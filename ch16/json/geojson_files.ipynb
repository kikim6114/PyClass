# %% [markdown]
# ## GeoJSON 파일
# #### GeoJSON 파일을 가독성 좋은 파일로 변환하기

# %%
from pathlib import Path
import json

# 문자열로 읽어들여 파이썬 객체로 변환.
path = Path('eq_data/eq_data_1_day_m1.geojson')
contents = path.read_text(encoding='utf-8')
all_eq_data = json.loads(contents)

# 가독성이 더 좋은 버전 만들기.
path = Path('eq_data/readable_eq_data.geojson')
readable_contents = json.dumps(all_eq_data, indent=4)
path.write_text(readable_contents)
# Out:
# 223652

# %% [markdown]
# ##### `eq_data_1_day_m1.geojson`의 내용

# %%
print(all_eq_data)
# Out:
# {'type': 'FeatureCollection', 'metadata': {'generated': 1649052296000, 'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_day.geojson', 'title': 'USGS Magnitude 1.0+ Earthquakes, Past Day', 'status': 200, 'api': '1.10.3', 'count': 160}, 'features': [{'type': 'Feature', 'properties': {'mag': 1.6, 'place': '27 km NNW of Susitna, Alaska', 'time': 1649051836769, 'updated': 1649052020437, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0224bju1jx', 'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0224bju1jx.geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'automatic', 'tsunami': 0, 'sig': 39, 'net': 'ak', 'code': '0224bju1jx', 'ids': ',ak0224bju1jx,', 'sources': ',ak,', 'types': ',origin,phase-data,', 'nst': None, 'dmin': None, 'rms': 0.54, 'gap': None, 'magType': 'ml', 'type': 'earthquake', 'title': 'M 1.6 - 27 km NNW of Susitna, Alaska'}, 'geometry': {'type': 'Point', 'coordinates': [-150.7585, 61.7591, 56.3]}, 'id': 'ak0224bju1jx'}, {'type': 'Feature', 'properties': {'mag': 1.6, 'place': '63 km SE of Pedro Bay, Alaska', 'time': 1649050396662, 'updated': 1649050785063, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0224bjowco', 'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0224bjowco.geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'automatic', 'tsunami': 0, 'sig': 39, 'net': 'ak', 'code': '0224bjowco', 'ids': ',ak0224bjowco,', 'sources': ',ak,', 'types': ',origin,phase-data,', 'nst': None, 'dmin': None, 'rms': 0.16, 'gap': None, 'magType': 'ml', 'type': 'earthquake', 'title': 'M 1.6 - 63 km SE of Pedro Bay, Alaska'}, 'geometry': {'type': 'Point', 'coordinates': [-153.4716, 59.3152, 97.9]}, 'id': 'ak0224bjowco'}, {'type': 'Feature', 'properties': {'mag': 2.2, 'place': '27 km SSE of Cantwell, Alaska', 'time': 1649049962786, 'updated': 1649050629179, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0224bjnd7y', 'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0224bjnd7y.geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'automatic', 'tsunami': 0, 'sig': 74, 'net': 'ak', 'code': '0224bjnd7y', 'ids': ',ak0224bjnd7y,', 'sources': ',ak,', 'types': ',origin,phase-data,', 'nst': None, 'dmin': None, 'rms': 0.53, 'gap': None, 'magType': 'ml', 'type': 'earthquake', 'title': 'M 2.2 - 27 km SSE of Cantwell, Alaska'}, 'geometry': {'type': 'Point', 'coordinates': [-148.7531, 63.1633, 52.6]}, 'id': 'ak0224bjnd7y'}, {'type': 'Feature', 'properties': {'mag': 3.7, 'place': '102 km SSE of Sand Point, Alaska', 'time': 1649049432877, 'updated': 1649051314040, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000gzhx', 'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000gzhx.geojson', 'felt': None, 'cdi': None, 'mmi': 2.317, 'alert': None, 'status': 'reviewed', 'tsunami': 0, 'sig': 211, 'net': 'us', 'code': '7000gzhx', 'ids': ',us7000gzhx,ak0224bjlgfu,', 'sources': ',us,ak,', 'types': ',origin,phase-data,shakemap,', 'nst': None, 'dmin': 0.271, 'rms': 0.6, 'gap': 194, 'magType': 'ml', 'type': 'earthquake', 'title': 'M 3.7 - 102 km SSE of Sand Point, Alaska'}, 'geometry': {'type': 'Point', 'coordinates': [-159.6267, 54.5612, 19.6]}, 'id': 'us7000gzhx'}, {'type': 'Feature', 'properties': {'mag': 2.92000008, 'place': '49 km SE of Naalehu, Hawaii', 'time': 1649048457870, 'updated': 1649051014040, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72972837', 'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72972837.geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'automatic', 'tsunami': 0, 'sig': 131, 'net': 'hv', 'code': '72972837', 'ids': ',us7000gzhs,hv72972837,', 'sources': ',us,hv,', 'types': ',origin,phase-data,', 'nst': 31, 'dmin': None, 'rms': 0.170000002, 'gap': 279, 'magType': 'md', 'type': 'earthquake', 'tit ...

# %% [markdown]
# ##### `readable_eq_data.geojson`의 내용

# %%
print(readable_contents)
# Out:
# {
#     "type": "FeatureCollection",
#     "metadata": {
#         "generated": 1649052296000,
#         "url": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_day.geojson",
#         "title": "USGS Magnitude 1.0+ Earthquakes, Past Day",
#         "status": 200,
#         "api": "1.10.3",
#         "count": 160
#     },
#     "features": [
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.6,
#                 "place": "27 km NNW of Susitna, Alaska",
#                 "time": 1649051836769,
#                 "updated": 1649052020437,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak0224bju1jx",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0224bju1jx.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 39,
#                 "net": "ak",
#                 "code": "0224bju1jx",
#                 "ids": ",ak0224bju1jx,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 0.54,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.6 - 27 km NNW of Susitna, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -150.7585,
#                     61.7591,
#                     56.3
#                 ]
#             },
#             "id": "ak0224bju1jx"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.6,
#                 "place": "63 km SE of Pedro Bay, Alaska",
#                 "time": 1649050396662,
#                 "updated": 1649050785063,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak0224bjowco",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0224bjowco.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 39,
#                 "net": "ak",
#                 "code": "0224bjowco",
#                 "ids": ",ak0224bjowco,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 0.16,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.6 - 63 km SE of Pedro Bay, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -153.4716,
#                     59.3152,
#                     97.9
#                 ]
#             },
#             "id": "ak0224bjowco"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 2.2,
#                 "place": "27 km SSE of Cantwell, Alaska",
#                 "time": 1649049962786,
#                 "updated": 1649050629179,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak0224bjnd7y",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0224bjnd7y.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 74,
#                 "net": "ak",
#                 "code": "0224bjnd7y",
#                 "ids": ",ak0224bjnd7y,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 0.53,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 2.2 - 27 km SSE of Cantwell, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -148.7531,
#                     63.1633,
#                     52.6
#                 ]
#             },
#             "id": "ak0224bjnd7y"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 3.7,
#                 "place": "102 km SSE of Sand Point, Alaska",
#                 "time": 1649049432877,
#                 "updated": 1649051314040,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gzhx",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000gzhx.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": 2.317,
#                 "alert": null,
#                 "status": "reviewed",
#                 "tsunami": 0,
#                 "sig": 211,
#                 "net": "us",
#                 "code": "7000gzhx",
#                 "ids": ",us7000gzhx,ak0224bjlgfu,",
#                 "sources": ",us,ak,",
#                 "types": ",origin,phase-data,shakemap,",
#                 "nst": null,
#                 "dmin": 0.271,
#                 "rms": 0.6,
#                 "gap": 194,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 3.7 - 102 km SSE of Sand Point, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -159.6267,
#                     54.5612,
#                     19.6
#                 ]
#             },
#             "id": "us7000gzhx"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 2.92000008,
#                 "place": "49 km SE of Naalehu, Hawaii",
#                 "time": 1649048457870,
#                 "updated": 1649051014040,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/hv72972837",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72972837.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 131,
#                 "net": "hv",
#                 "code": "72972837",
#                 "ids": ",us7000gzhs,hv72972837,",
#                 "sources": ",us,hv,",
#                 "types": ",origin,phase-data,",
#                 "nst": 31,
#                 "dmin": null,
#                 "rms": 0.170000002,
#                 "gap": 279,
#                 "magType": "md",
#                 "type": "earthquake",
#                 "title": "M 2.9 - 49 km SE of Naalehu, Hawaii"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -155.248336791992,
#                     18.7551670074463,
#                     8.6899995803833
#                 ]
#             },
#             "id": "hv72972837"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.4,
#                 "place": "44 km NE of Susitna North, Alaska",
#                 "time": 1649047203059,
#                 "updated": 1649047331776,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak0224bj4xpt",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0224bj4xpt.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 30,
#                 "net": "ak",
#                 "code": "0224bj4xpt",
#                 "ids": ",ak0224bj4xpt,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 0.74,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.4 - 44 km NE of Susitna North, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -149.173,
#                     62.3994,
#                     35.6
#                 ]
#             },
#             "id": "ak0224bj4xpt"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 4.6,
#                 "place": "49 km SSE of Kor\u00f3ni, Greece",
#                 "time": 1649047182232,
#                 "updated": 1649049053040,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gzhn",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000gzhn.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "reviewed",
#                 "tsunami": 0,
#                 "sig": 326,
#                 "net": "us",
#                 "code": "7000gzhn",
#                 "ids": ",us7000gzhn,",
#                 "sources": ",us,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": 0.827,
#                 "rms": 0.84,
#                 "gap": 117,
#                 "magType": "mb",
#                 "type": "earthquake",
#                 "title": "M 4.6 - 49 km SSE of Kor\u00f3ni, Greece"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     22.0768,
#                     36.3592,
#                     35.27
#                 ]
#             },
#             "id": "us7000gzhn"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 4.5,
#                 "place": "Banda Sea",
#                 "time": 1649046384834,
#                 "updated": 1649048402040,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gzhl",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000gzhl.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "reviewed",
#                 "tsunami": 0,
#                 "sig": 312,
#                 "net": "us",
#                 "code": "7000gzhl",
#                 "ids": ",us7000gzhl,",
#                 "sources": ",us,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": 2.194,
#                 "rms": 0.78,
#                 "gap": 65,
#                 "magType": "mb",
#                 "type": "earthquake",
#                 "title": "M 4.5 - Banda Sea"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     129.5079,
#                     -6.686,
#                     149.73
#                 ]
#             },
#             "id": "us7000gzhl"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.9,
#                 "place": "54 km N of Petersville, Alaska",
#                 "time": 1649046245122,
#                 "updated": 1649046875802,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak0224bj1ie2",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0224bj1ie2.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 56,
#                 "net": "ak",
#                 "code": "0224bj1ie2",
#                 "ids": ",ak0224bj1ie2,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 0.55,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.9 - 54 km N of Petersville, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -150.5896,
#                     62.9779,
#                     90.2
#                 ]
#             },
#             "id": "ak0224bj1ie2"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.8,
#                 "place": "34 km SSW of Fort Greely, Alaska",
#                 "time": 1649045264214,
#                 "updated": 1649046448640,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak0224bixy9k",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0224bixy9k.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 50,
#                 "net": "ak",
#                 "code": "0224bixy9k",
#                 "ids": ",ak0224bixy9k,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 0.43,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.8 - 34 km SSW of Fort Greely, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -145.9089,
#                     63.671,
#                     0
#                 ]
#             },
#             "id": "ak0224bixy9k"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.7,
#                 "place": "121 km NW of Yakutat, Alaska",
#                 "time": 1649045014302,
#                 "updated": 1649045749969,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak0224bix2mu",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0224bix2mu.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 44,
#                 "net": "ak",
#                 "code": "0224bix2mu",
#                 "ids": ",ak0224bix2mu,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 0.73,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.7 - 121 km NW of Yakutat, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -141.4547,
#                     60.2138,
#                     0
#                 ]
#             },
#             "id": "ak0224bix2mu"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 4.1,
#                 "place": "77 km W of Tobelo, Indonesia",
#                 "time": 1649044907085,
#                 "updated": 1649047498040,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gzhj",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000gzhj.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "reviewed",
#                 "tsunami": 0,
#                 "sig": 259,
#                 "net": "us",
#                 "code": "7000gzhj",
#                 "ids": ",us7000gzhj,",
#                 "sources": ",us,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": 1.005,
#                 "rms": 0.45,
#                 "gap": 121,
#                 "magType": "mb",
#                 "type": "earthquake",
#                 "title": "M 4.1 - 77 km W of Tobelo, Indonesia"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     127.3132,
#                     1.7827,
#                     120.58
#                 ]
#             },
#             "id": "us7000gzhj"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.6,
#                 "place": "61 km S of Cantwell, Alaska",
#                 "time": 1649044587407,
#                 "updated": 1649045350347,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak0224bimzfz",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0224bimzfz.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 39,
#                 "net": "ak",
#                 "code": "0224bimzfz",
#                 "ids": ",ak0224bimzfz,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 0.6,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.6 - 61 km S of Cantwell, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -148.8272,
#                     62.8383,
#                     13.3
#                 ]
#             },
#             "id": "ak0224bimzfz"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.2,
#                 "place": "35 km SE of Mina, Nevada",
#                 "time": 1649042461891,
#                 "updated": 1649042696450,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nn00836645",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00836645.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 22,
#                 "net": "nn",
#                 "code": "00836645",
#                 "ids": ",nn00836645,",
#                 "sources": ",nn,",
#                 "types": ",origin,phase-data,",
#                 "nst": 11,
#                 "dmin": 0.133,
#                 "rms": 0.1997,
#                 "gap": 206.36,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.2 - 35 km SE of Mina, Nevada"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -117.7935,
#                     38.1911,
#                     0
#                 ]
#             },
#             "id": "nn00836645"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 5.1,
#                 "place": "97 km NNE of Fais, Micronesia",
#                 "time": 1649042218253,
#                 "updated": 1649044021040,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gzhf",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000gzhf.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "reviewed",
#                 "tsunami": 0,
#                 "sig": 400,
#                 "net": "us",
#                 "code": "7000gzhf",
#                 "ids": ",us7000gzhf,",
#                 "sources": ",us,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": 4.994,
#                 "rms": 1.17,
#                 "gap": 35,
#                 "magType": "mb",
#                 "type": "earthquake",
#                 "title": "M 5.1 - 97 km NNE of Fais, Micronesia"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     140.7506,
#                     10.6172,
#                     10
#                 ]
#             },
#             "id": "us7000gzhf"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.02,
#                 "place": "5km SE of Redlands, CA",
#                 "time": 1649040879960,
#                 "updated": 1649041098340,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ci39985583",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39985583.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 16,
#                 "net": "ci",
#                 "code": "39985583",
#                 "ids": ",ci39985583,",
#                 "sources": ",ci,",
#                 "types": ",nearby-cities,origin,phase-data,scitech-link,",
#                 "nst": 30,
#                 "dmin": 0.03617,
#                 "rms": 0.21,
#                 "gap": 130,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.0 - 5km SE of Redlands, CA"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -117.153,
#                     34.0223333,
#                     8.69
#                 ]
#             },
#             "id": "ci39985583"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.8,
#                 "place": "31 km WNW of Central, Alaska",
#                 "time": 1649040311777,
#                 "updated": 1649040579878,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak0224bhz5qj",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0224bhz5qj.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 50,
#                 "net": "ak",
#                 "code": "0224bhz5qj",
#                 "ids": ",ak0224bhz5qj,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 0.76,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.8 - 31 km WNW of Central, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -145.4421,
#                     65.6749,
#                     4.2
#                 ]
#             },
#             "id": "ak0224bhz5qj"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 2.78,
#                 "place": "16km NW of Pinnacles, CA",
#                 "time": 1649040174140,
#                 "updated": 1649050812374,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc73713976",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73713976.geojson",
#                 "felt": 4,
#                 "cdi": 3.1,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 120,
#                 "net": "nc",
#                 "code": "73713976",
#                 "ids": ",nc73713976,us7000gzh8,",
#                 "sources": ",nc,us,",
#                 "types": ",dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,",
#                 "nst": 45,
#                 "dmin": 0.05088,
#                 "rms": 0.08,
#                 "gap": 66,
#                 "magType": "md",
#                 "type": "earthquake",
#                 "title": "M 2.8 - 16km NW of Pinnacles, CA"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -121.2634964,
#                     36.6408348,
#                     10.61
#                 ]
#             },
#             "id": "nc73713976"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 2.29,
#                 "place": "3 km S of Gu\u00e1nica, Puerto Rico",
#                 "time": 1649039623330,
#                 "updated": 1649043326070,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/pr71343293",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71343293.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "reviewed",
#                 "tsunami": 0,
#                 "sig": 81,
#                 "net": "pr",
#                 "code": "71343293",
#                 "ids": ",pr71343293,",
#                 "sources": ",pr,",
#                 "types": ",origin,phase-data,",
#                 "nst": 7,
#                 "dmin": null,
#                 "rms": 0.1,
#                 "gap": 217,
#                 "magType": "md",
#                 "type": "earthquake",
#                 "title": "M 2.3 - 3 km S of Gu\u00e1nica, Puerto Rico"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -66.9111666666667,
#                     17.9403333333333,
#                     12.36
#                 ]
#             },
#             "id": "pr71343293"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 0.98,
#                 "place": "1km S of Loma Linda, CA",
#                 "time": 1649039563290,
#                 "updated": 1649039787071,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ci39985567",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39985567.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 15,
#                 "net": "ci",
#                 "code": "39985567",
#                 "ids": ",ci39985567,",
#                 "sources": ",ci,",
#                 "types": ",nearby-cities,origin,phase-data,scitech-link,",
#                 "nst": 21,
#                 "dmin": 0.1059,
#                 "rms": 0.19,
#                 "gap": 135,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.0 - 1km S of Loma Linda, CA"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -117.2585,
#                     34.0358333,
#                     15.82
#                 ]
#             },
#             "id": "ci39985567"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 2.5,
#                 "place": "88 km W of Akhiok, Alaska",
#                 "time": 1649039202094,
#                 "updated": 1649039494388,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak0224bhv5h1",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0224bhv5h1.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 96,
#                 "net": "ak",
#                 "code": "0224bhv5h1",
#                 "ids": ",ak0224bhv5h1,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 0.63,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 2.5 - 88 km W of Akhiok, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -155.6147,
#                     57.0429,
#                     57
#                 ]
#             },
#             "id": "ak0224bhv5h1"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.79,
#                 "place": "17km SE of Big Bear City, CA",
#                 "time": 1649039149970,
#                 "updated": 1649039810460,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ci39985559",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39985559.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 49,
#                 "net": "ci",
#                 "code": "39985559",
#                 "ids": ",ci39985559,",
#                 "sources": ",ci,",
#                 "types": ",focal-mechanism,nearby-cities,origin,phase-data,scitech-link,",
#                 "nst": 56,
#                 "dmin": 0.1249,
#                 "rms": 0.15,
#                 "gap": 32,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.8 - 17km SE of Big Bear City, CA"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -116.7213333,
#                     34.1478333,
#                     -0.6
#                 ]
#             },
#             "id": "ci39985559"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.4,
#                 "place": "35 km NNE of Rampart, Alaska",
#                 "time": 1649038647017,
#                 "updated": 1649039085810,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak0224bht6st",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0224bht6st.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 30,
#                 "net": "ak",
#                 "code": "0224bht6st",
#                 "ids": ",ak0224bht6st,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 0.81,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.4 - 35 km NNE of Rampart, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -149.8307,
#                     65.7868,
#                     0
#                 ]
#             },
#             "id": "ak0224bht6st"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.13,
#                 "place": "1km NNW of The Geysers, CA",
#                 "time": 1649038080350,
#                 "updated": 1649047395002,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc73713961",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73713961.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 20,
#                 "net": "nc",
#                 "code": "73713961",
#                 "ids": ",nc73713961,",
#                 "sources": ",nc,",
#                 "types": ",nearby-cities,origin,phase-data,scitech-link,",
#                 "nst": 16,
#                 "dmin": 0.01249,
#                 "rms": 0.06,
#                 "gap": 65,
#                 "magType": "md",
#                 "type": "earthquake",
#                 "title": "M 1.1 - 1km NNW of The Geysers, CA"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -122.7611694,
#                     38.788166,
#                     1.48
#                 ]
#             },
#             "id": "nc73713961"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.13,
#                 "place": "13km SE of Anza, CA",
#                 "time": 1649037572090,
#                 "updated": 1649037793226,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ci39985543",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39985543.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 20,
#                 "net": "ci",
#                 "code": "39985543",
#                 "ids": ",ci39985543,",
#                 "sources": ",ci,",
#                 "types": ",nearby-cities,origin,phase-data,scitech-link,",
#                 "nst": 40,
#                 "dmin": 0.03575,
#                 "rms": 0.16,
#                 "gap": 48,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.1 - 13km SE of Anza, CA"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -116.5603333,
#                     33.4873333,
#                     7.62
#                 ]
#             },
#             "id": "ci39985543"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 4.4,
#                 "place": "10 km E of Yujing, Taiwan",
#                 "time": 1649037047508,
#                 "updated": 1649042835040,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gzh2",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000gzh2.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "reviewed",
#                 "tsunami": 0,
#                 "sig": 298,
#                 "net": "us",
#                 "code": "7000gzh2",
#                 "ids": ",us7000gzh2,",
#                 "sources": ",us,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": 0.172,
#                 "rms": 1,
#                 "gap": 89,
#                 "magType": "mb",
#                 "type": "earthquake",
#                 "title": "M 4.4 - 10 km E of Yujing, Taiwan"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     120.5613,
#                     23.1392,
#                     13.35
#                 ]
#             },
#             "id": "us7000gzh2"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.3,
#                 "place": "20 km NNW of Sutcliffe, Nevada",
#                 "time": 1649036920361,
#                 "updated": 1649037115890,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nn00836644",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00836644.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 26,
#                 "net": "nn",
#                 "code": "00836644",
#                 "ids": ",nn00836644,",
#                 "sources": ",nn,",
#                 "types": ",origin,phase-data,",
#                 "nst": 8,
#                 "dmin": 0.073,
#                 "rms": 0.1111,
#                 "gap": 164.36,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.3 - 20 km NNW of Sutcliffe, Nevada"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -119.6498,
#                     40.133,
#                     3.7
#                 ]
#             },
#             "id": "nn00836644"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.18,
#                 "place": "8km W of Cobb, CA",
#                 "time": 1649036829560,
#                 "updated": 1649043375602,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc73713941",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73713941.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 21,
#                 "net": "nc",
#                 "code": "73713941",
#                 "ids": ",nc73713941,",
#                 "sources": ",nc,",
#                 "types": ",nearby-cities,origin,phase-data,scitech-link,",
#                 "nst": 15,
#                 "dmin": 0.009777,
#                 "rms": 0.01,
#                 "gap": 51,
#                 "magType": "md",
#                 "type": "earthquake",
#                 "title": "M 1.2 - 8km W of Cobb, CA"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -122.8125,
#                     38.8330002,
#                     1.74
#                 ]
#             },
#             "id": "nc73713941"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.4,
#                 "place": "44 km ESE of Knik River, Alaska",
#                 "time": 1649036768341,
#                 "updated": 1649037582960,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak0224bhdxlu",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0224bhdxlu.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 30,
#                 "net": "ak",
#                 "code": "0224bhdxlu",
#                 "ids": ",ak0224bhdxlu,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 0.49,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.4 - 44 km ESE of Knik River, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -148.1118,
#                     61.3358,
#                     19.1
#                 ]
#             },
#             "id": "ak0224bhdxlu"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.49,
#                 "place": "17km NW of Morongo Valley, CA",
#                 "time": 1649036474370,
#                 "updated": 1649036703846,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ci39985511",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39985511.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 34,
#                 "net": "ci",
#                 "code": "39985511",
#                 "ids": ",ci39985511,",
#                 "sources": ",ci,",
#                 "types": ",nearby-cities,origin,phase-data,scitech-link,",
#                 "nst": 44,
#                 "dmin": 0.1236,
#                 "rms": 0.22,
#                 "gap": 32,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.5 - 17km NW of Morongo Valley, CA"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -116.7225,
#                     34.1458333,
#                     -0.6
#                 ]
#             },
#             "id": "ci39985511"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 2.8,
#                 "place": "206 km SE of Chiniak, Alaska",
#                 "time": 1649033617215,
#                 "updated": 1649035365040,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gzgy",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000gzgy.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "reviewed",
#                 "tsunami": 0,
#                 "sig": 121,
#                 "net": "us",
#                 "code": "7000gzgy",
#                 "ids": ",us7000gzgy,",
#                 "sources": ",us,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": 2.087,
#                 "rms": 0.44,
#                 "gap": 290,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 2.8 - 206 km SE of Chiniak, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -149.5698,
#                     56.4973,
#                     10
#                 ]
#             },
#             "id": "us7000gzgy"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.14,
#                 "place": "3km SE of Chino, CA",
#                 "time": 1649032945530,
#                 "updated": 1649033159499,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ci39985487",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39985487.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 20,
#                 "net": "ci",
#                 "code": "39985487",
#                 "ids": ",ci39985487,",
#                 "sources": ",ci,",
#                 "types": ",nearby-cities,origin,phase-data,scitech-link,",
#                 "nst": 9,
#                 "dmin": 0.2777,
#                 "rms": 0.22,
#                 "gap": 100,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.1 - 3km SE of Chino, CA"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -117.6645,
#                     33.9961667,
#                     4.66
#                 ]
#             },
#             "id": "ci39985487"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.22,
#                 "place": "8km WNW of Cobb, CA",
#                 "time": 1649032210800,
#                 "updated": 1649041816460,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc73713931",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73713931.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 23,
#                 "net": "nc",
#                 "code": "73713931",
#                 "ids": ",nc73713931,",
#                 "sources": ",nc,",
#                 "types": ",nearby-cities,origin,phase-data,scitech-link,",
#                 "nst": 15,
#                 "dmin": 0.01425,
#                 "rms": 0.09,
#                 "gap": 61,
#                 "magType": "md",
#                 "type": "earthquake",
#                 "title": "M 1.2 - 8km WNW of Cobb, CA"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -122.8128357,
#                     38.8375015,
#                     -0.38
#                 ]
#             },
#             "id": "nc73713931"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.8,
#                 "place": "37 km NW of Silver Peak, Nevada",
#                 "time": 1649032071527,
#                 "updated": 1649032296160,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nn00836639",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00836639.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 50,
#                 "net": "nn",
#                 "code": "00836639",
#                 "ids": ",nn00836639,",
#                 "sources": ",nn,",
#                 "types": ",origin,phase-data,",
#                 "nst": 19,
#                 "dmin": 0.023,
#                 "rms": 0.3445,
#                 "gap": 115.19,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.8 - 37 km NW of Silver Peak, Nevada"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -117.8823,
#                     38.0322,
#                     3.3
#                 ]
#             },
#             "id": "nn00836639"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.6600000000000001,
#                 "place": "9 km SSE of Desert Aire, Washington",
#                 "time": 1649031925520,
#                 "updated": 1649047441190,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/uw61827646",
# ...
#                 "sources": ",nn,",
#                 "types": ",origin,phase-data,",
#                 "nst": 10,
#                 "dmin": 0.105,
#                 "rms": 0.0718,
#                 "gap": 191.92,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.1 - 29 km SE of Mina, Nevada"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -117.8612,
#                     38.2105,
#                     8.7
#                 ]
#             },
#             "id": "nn00836611"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.9,
#                 "place": "10 km NE of Willow, Alaska",
#                 "time": 1648974227792,
#                 "updated": 1648974593152,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak02249xvrxg",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak02249xvrxg.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 56,
#                 "net": "ak",
#                 "code": "02249xvrxg",
#                 "ids": ",ak02249xvrxg,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 0.56,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.9 - 10 km NE of Willow, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -149.9064,
#                     61.815,
#                     24.5
#                 ]
#             },
#             "id": "ak02249xvrxg"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.7,
#                 "place": "66 km SE of Pedro Bay, Alaska",
#                 "time": 1648973779804,
#                 "updated": 1648974044354,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak02249xu7r9",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak02249xu7r9.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 44,
#                 "net": "ak",
#                 "code": "02249xu7r9",
#                 "ids": ",ak02249xu7r9,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 0.34,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.7 - 66 km SE of Pedro Bay, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -153.2027,
#                     59.41,
#                     103.6
#                 ]
#             },
#             "id": "ak02249xu7r9"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 2.1,
#                 "place": "34 km NNE of Chase, Alaska",
#                 "time": 1648972914554,
#                 "updated": 1648973076546,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak02249xr2n1",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak02249xr2n1.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 68,
#                 "net": "ak",
#                 "code": "02249xr2n1",
#                 "ids": ",ak02249xr2n1,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 0.72,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 2.1 - 34 km NNE of Chase, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -149.8562,
#                     62.7391,
#                     45.4
#                 ]
#             },
#             "id": "ak02249xr2n1"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.03,
#                 "place": "20 km S of Packwood, Washington",
#                 "time": 1648972244340,
#                 "updated": 1649047431170,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/uw61827566",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uw61827566.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "reviewed",
#                 "tsunami": 0,
#                 "sig": 16,
#                 "net": "uw",
#                 "code": "61827566",
#                 "ids": ",uw61827566,",
#                 "sources": ",uw,",
#                 "types": ",origin,phase-data,",
#                 "nst": 19,
#                 "dmin": 0.2456,
#                 "rms": 0.16,
#                 "gap": 134,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.0 - 20 km S of Packwood, Washington"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -121.63783333333333,
#                     46.428,
#                     0.1
#                 ]
#             },
#             "id": "uw61827566"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 4.1,
#                 "place": "17 km W of Hulbuk, Tajikistan",
#                 "time": 1648972096956,
#                 "updated": 1648974023040,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gzbg",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000gzbg.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "reviewed",
#                 "tsunami": 0,
#                 "sig": 259,
#                 "net": "us",
#                 "code": "7000gzbg",
#                 "ids": ",us7000gzbg,",
#                 "sources": ",us,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": 1.124,
#                 "rms": 0.41,
#                 "gap": 146,
#                 "magType": "mb",
#                 "type": "earthquake",
#                 "title": "M 4.1 - 17 km W of Hulbuk, Tajikistan"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     69.4435,
#                     37.799,
#                     10
#                 ]
#             },
#             "id": "us7000gzbg"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.18,
#                 "place": "15 km SE of Lincoln, Montana",
#                 "time": 1648971215540,
#                 "updated": 1648995029180,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/mb80542034",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/mb80542034.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "reviewed",
#                 "tsunami": 0,
#                 "sig": 21,
#                 "net": "mb",
#                 "code": "80542034",
#                 "ids": ",mb80542034,",
#                 "sources": ",mb,",
#                 "types": ",origin,phase-data,",
#                 "nst": 15,
#                 "dmin": 0.045,
#                 "rms": 0.15,
#                 "gap": 60,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.2 - 15 km SE of Lincoln, Montana"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -112.5198333,
#                     46.871,
#                     14.35
#                 ]
#             },
#             "id": "mb80542034"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 0.96,
#                 "place": "17km ESE of Anza, CA",
#                 "time": 1648970534600,
#                 "updated": 1648970755530,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ci39985055",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39985055.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 14,
#                 "net": "ci",
#                 "code": "39985055",
#                 "ids": ",ci39985055,",
#                 "sources": ",ci,",
#                 "types": ",nearby-cities,origin,phase-data,scitech-link,",
#                 "nst": 36,
#                 "dmin": 0.06734,
#                 "rms": 0.2,
#                 "gap": 59,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.0 - 17km ESE of Anza, CA"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -116.501,
#                     33.4948333,
#                     12.89
#                 ]
#             },
#             "id": "ci39985055"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.83,
#                 "place": "4 km SSE of Gu\u00e1nica, Puerto Rico",
#                 "time": 1648970331430,
#                 "updated": 1648972156200,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/pr71343193",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71343193.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "reviewed",
#                 "tsunami": 0,
#                 "sig": 52,
#                 "net": "pr",
#                 "code": "71343193",
#                 "ids": ",pr71343193,",
#                 "sources": ",pr,",
#                 "types": ",origin,phase-data,",
#                 "nst": 10,
#                 "dmin": null,
#                 "rms": 0.12,
#                 "gap": 219,
#                 "magType": "md",
#                 "type": "earthquake",
#                 "title": "M 1.8 - 4 km SSE of Gu\u00e1nica, Puerto Rico"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -66.8955,
#                     17.9311666666667,
#                     13.16
#                 ]
#             },
#             "id": "pr71343193"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 3.2,
#                 "place": "85 km ESE of King Cove, Alaska",
#                 "time": 1648969356972,
#                 "updated": 1648972154040,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gzbb",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000gzbb.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "reviewed",
#                 "tsunami": 0,
#                 "sig": 158,
#                 "net": "us",
#                 "code": "7000gzbb",
#                 "ids": ",us7000gzbb,",
#                 "sources": ",us,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": 0.799,
#                 "rms": 0.58,
#                 "gap": 178,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 3.2 - 85 km ESE of King Cove, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -161.2079,
#                     54.6414,
#                     24.16
#                 ]
#             },
#             "id": "us7000gzbb"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.22,
#                 "place": "7km SW of Inverness, CA",
#                 "time": 1648968971330,
#                 "updated": 1649032216462,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc73713636",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73713636.geojson",
#                 "felt": 1,
#                 "cdi": 2.2,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "reviewed",
#                 "tsunami": 0,
#                 "sig": 23,
#                 "net": "nc",
#                 "code": "73713636",
#                 "ids": ",nc73713636,",
#                 "sources": ",nc,",
#                 "types": ",dyfi,nearby-cities,origin,phase-data,scitech-link,",
#                 "nst": 17,
#                 "dmin": 0.05802,
#                 "rms": 0.11,
#                 "gap": 99,
#                 "magType": "md",
#                 "type": "earthquake",
#                 "title": "M 1.2 - 7km SW of Inverness, CA"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -122.9035,
#                     38.0496667,
#                     8.51
#                 ]
#             },
#             "id": "nc73713636"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.71,
#                 "place": "13km WNW of Anza, CA",
#                 "time": 1648967371100,
#                 "updated": 1648990769150,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ci39985047",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39985047.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "reviewed",
#                 "tsunami": 0,
#                 "sig": 45,
#                 "net": "ci",
#                 "code": "39985047",
#                 "ids": ",ci39985047,",
#                 "sources": ",ci,",
#                 "types": ",focal-mechanism,nearby-cities,origin,phase-data,scitech-link,",
#                 "nst": 64,
#                 "dmin": 0.05586,
#                 "rms": 0.19,
#                 "gap": 22,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.7 - 13km WNW of Anza, CA"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -116.8085,
#                     33.5846667,
#                     8.04
#                 ]
#             },
#             "id": "ci39985047"
#         }
#     ],
#     "bbox": [
#         -173.0821,
#         -57.4218,
#         -0.6,
#         170.0847,
#         65.7868,
#         201.27
#     ]
# }

# %% [markdown]
# #### 모든 지진의 목록 만들기

# %%
# 데이터셋 내 모든 지진 살펴보기.
all_eq_dicts = all_eq_data['features']
print(len(all_eq_dicts))
# Out:
# 160

# %% [markdown]
# #### 지진 규모 추출

# %%
mags = []
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    mags.append(mag)

print(mags[:10])
# Out:
# [1.6, 1.6, 2.2, 3.7, 2.92000008, 1.4, 4.6, 4.5, 1.9, 1.8]

# %% [markdown]
# #### 위치 데이터 추출

# %%
mags, lons, lats = [], [], []
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    lon = eq_dict['geometry']['coordinates'][0]
    lat = eq_dict['geometry']['coordinates'][1]
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)

print(mags[:10])
print(lons[:5])
print(lats[:5])
# Out:
# [1.6, 1.6, 2.2, 3.7, 2.92000008, 1.4, 4.6, 4.5, 1.9, 1.8]
# [-150.7585, -153.4716, -148.7531, -159.6267, -155.248336791992]
# [61.7591, 59.3152, 63.1633, 54.5612, 18.7551670074463]

# %% [markdown]
# #### Plotly를 사용한 세계 지도 그리기

# %%
import plotly.express as px

title = '세계 지진 지도'
fig = px.scatter_geo(lat=lats, lon=lons, title=title)
fig.update_layout(title_x = 0.5, title_y = 0.85)

fig.write_html('images/eq_world_map.html')
fig.show()

# %% [markdown]
# #### 지진 규모 표시

# %%
# 문자열로 읽어들여 파이썬 객체로 변환.
path = Path('eq_data/eq_data_30_day_m1.geojson')
contents = path.read_text(encoding='utf-8')
all_eq_data = json.loads(contents)

# 데이터셋 내 모든 지진 살펴보기.
all_eq_dicts = all_eq_data['features']

mags, lons, lats = [], [], []
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    lon = eq_dict['geometry']['coordinates'][0]
    lat = eq_dict['geometry']['coordinates'][1]
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)

title = '세계 지진 지도'
fig = px.scatter_geo(lat=lats, lon=lons, size=mags, title=title)
fig.update_layout(title_x = 0.5, title_y = 0.85)

fig.write_html('images/eq_world_map_magnitudes.html')
fig.show()

# %% [markdown]
# #### 마커 칼라 바꾸기

# %%
fig = px.scatter_geo(lat=lats, lon=lons, size=mags, title=title,
        color=mags,
        color_continuous_scale='Viridis',
        labels={'color':'Magnitude'},
        projection='natural earth',
        width= 1200,
        height=800,
    )
fig.update_layout(title_x = 0.5, title_y = 0.85)

fig.write_html('images/eq_world_map_magnitudes_colors.html')
fig.show()

# %%
print(px.colors.named_colorscales())
# Out:
# ['aggrnyl', 'agsunset', 'blackbody', 'bluered', 'blues', 'blugrn', 'bluyl', 'brwnyl', 'bugn', 'bupu', 'burg', 'burgyl', 'cividis', 'darkmint', 'electric', 'emrld', 'gnbu', 'greens', 'greys', 'hot', 'inferno', 'jet', 'magenta', 'magma', 'mint', 'orrd', 'oranges', 'oryel', 'peach', 'pinkyl', 'plasma', 'plotly3', 'pubu', 'pubugn', 'purd', 'purp', 'purples', 'purpor', 'rainbow', 'rdbu', 'rdpu', 'redor', 'reds', 'sunset', 'sunsetdark', 'teal', 'tealgrn', 'turbo', 'viridis', 'ylgn', 'ylgnbu', 'ylorbr', 'ylorrd', 'algae', 'amp', 'deep', 'dense', 'gray', 'haline', 'ice', 'matter', 'solar', 'speed', 'tempo', 'thermal', 'turbid', 'armyrose', 'brbg', 'earth', 'fall', 'geyser', 'prgn', 'piyg', 'picnic', 'portland', 'puor', 'rdgy', 'rdylbu', 'rdylgn', 'spectral', 'tealrose', 'temps', 'tropic', 'balance', 'curl', 'delta', 'oxy', 'edge', 'hsv', 'icefire', 'phase', 'twilight', 'mrybm', 'mygbm']

# %% [markdown]
# #### 호버(Hover) 효과 추가하기

# %%
# 문자열로 읽어들여 파이썬 객체로 변환.
path = Path('eq_data/eq_data_30_day_m1.geojson')
contents = path.read_text(encoding='utf-8')
all_eq_data = json.loads(contents)

# 데이터셋 내 모든 지진 살펴보기.
all_eq_dicts = all_eq_data['features']

mags, lons, lats, eq_titles = [], [], [], []
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    lon = eq_dict['geometry']['coordinates'][0]
    lat = eq_dict['geometry']['coordinates'][1]
    eq_title = eq_dict['properties']['title']
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)
    eq_titles.append(eq_title)

title = '세계 지진 지도'
fig = px.scatter_geo(lat=lats, lon=lons, size=mags, title=title,
        color=mags,
        color_continuous_scale='Viridis',
        labels={'color':'Magnitude'},
        projection='natural earth',
        hover_name=eq_titles,
        width= 1200,
        height=800,
    )
fig.update_layout(title_x = 0.5, title_y = 0.85)

fig.write_html('images/eq_world_map_magnitudes_hover.html')
fig.show()
