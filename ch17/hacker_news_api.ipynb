# %% [markdown]
# ## 해처 뉴스 API
# #### API 호출

# %%
import requests
import json

# API 호출하고 응답 체크.
url = "https://hacker-news.firebaseio.com/v0/item/31353677.json"
r = requests.get(url)
print(f"Status code: {r.status_code}")

# 데이터 구조 탐색.
response_dict = r.json()
response_string = json.dumps(response_dict, indent=4)
print(response_string)
# Out:
# Status code: 200
# {
#     "by": "sohkamyung",
#     "descendants": 307,
#     "id": 31353677,
#     "kids": [
#         31354987,
#         31354235,
#         31354040,
#         31358602,
#         31354201,
#         31354991,
#         31354315,
#         31353775,
#         31353925,
#         31354169,
#         31354273,
#         31354437,
#         31356902,
#         31358694,
#         31363418,
#         31353862,
#         31357186,
#         31356379,
#         31356826,
#         31355085,
#         31369435,
#         31357936,
#         31354142,
#         31354213,
#         31356311,
#         31357865,
#         31353929,
#         31364954,
#         31354621,
#         31356002,
#         31356407,
#         31355491,
#         31359235,
#         31356053,
#         31354347,
#         31355326,
#         31354703,
#         31353802
#     ],
#     "score": 786,
#     "time": 1652361401,
#     "title": "Astronomers reveal first image of the black hole at the heart of our galaxy",
#     "type": "story",
#     "url": "https://public.nrao.edu/news/astronomers-reveal-first-image-of-the-black-hole-at-the-heart-of-our-galaxy/"
# }

# %% [markdown]
# #### 현재 해커 뉴스 상위 게시글 ID 보기

# %%
from operator import itemgetter
import requests

# API 호출하고 응답 체크.
url = 'https://hacker-news.firebaseio.com/v0/topstories.json'
r = requests.get(url)
print(f"Status code: {r.status_code}")

# 각 게시물에 대한 정보 처리.
submission_ids = r.json()

submission_dicts = []
for submission_id in submission_ids[:30]:
    # 각 게시물에 대한 신규 API call.
    url = f"https://hacker-news.firebaseio.com/v0/item/{submission_id}.json"
    r = requests.get(url)
    print(f"id: {submission_id}\tstatus: {r.status_code}")
    response_dict = r.json()
    
    # 각 기사에 대한 딕셔너리 구축.
    submission_dict = {
        'title': response_dict['title'],
        'hn_link': f"https://news.ycombinator.com/item?id={submission_id}",
        'comments': response_dict['descendants'],
    }
    submission_dicts.append(submission_dict)

submission_dicts = sorted(submission_dicts, key=itemgetter('comments'),
                            reverse=True)

for submission_dict in submission_dicts:
    print(f"\nTitle: {submission_dict['title']}")
    print(f"Discussion link: {submission_dict['hn_link']}")
    print(f"Comments: {submission_dict['comments']}")
# Out:
# Status code: 200
# id: 43933891	status: 200
# id: 43927926	status: 200
# id: 43933452	status: 200
# id: 43933628	status: 200
# id: 43933412	status: 200
# id: 43928315	status: 200
# id: 43931845	status: 200
# id: 43933511	status: 200
# id: 43933605	status: 200
# id: 43931409	status: 200
# id: 43933683	status: 200
# id: 43893581	status: 200
# id: 43927337	status: 200
# id: 43929724	status: 200
# id: 43933548	status: 200
# id: 43908261	status: 200
# id: 43926324	status: 200
# id: 43931944	status: 200
# id: 43899456	status: 200
# id: 43905153	status: 200
# id: 43933248	status: 200
# id: 43932567	status: 200
# id: 43902350	status: 200
# id: 43931673	status: 200
# id: 43930584	status: 200
# id: 43927856	status: 200
# id: 43929054	status: 200
# id: 43928118	status: 200
# id: 43930397	status: 200
# id: 43929447	status: 200
#
# Title: First American pope elected and will be known as Pope Leo XIV
# Discussion link: https://news.ycombinator.com/item?id=43927856
# Comments: 804
#
# Title: Void: Open-source Cursor alternative
# Discussion link: https://news.ycombinator.com/item?id=43927926
# Comments: 276
#
